# %%
## Old way to use formatting

# %%
print('(%s) - (%s) - (%s) ' %  ('PJXIO' , 'Fury' , 'Sa'))
# Out:
# (PJXIO) - (Fury) - (Sa)

# %%
## New ways to format

# %%
name = 'PJXIO'
middlename = 'Fury'
Country = 'Sa'

# %%
print(f"{'PJXIO'} - {'Fury'} - {'Sa'}")
# Out:
# PJXIO - Fury - Sa

# %%
print(f"{name.lower()} - {middlename.swapcase()} - {Country.upper()}")
# Out:
# pjxio - fURY - SA
